# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st

# %%
df=pd.read_csv('Salary_Data.csv')
df
x=df['YearsExperience']
y=df['Salary']
print(df)
# Out:
#     YearsExperience    Salary      Position  Gender
# 0               1.1   39343.0     Developer    Male
# 1               1.3   46205.0  Data Analyst    Male
# 2               1.5   37731.0  Data Analyst  Female
# 3               2.0   43525.0  Data Analyst  Female
# 4               2.2   39891.0  Data Analyst  Female
# 5               2.9   56642.0  Data Analyst  Female
# 6               3.0   60150.0     Developer    Male
# 7               3.2   54445.0     Developer    Male
# 8               3.2   64445.0        Tester  Female
# 9               3.7   57189.0        Tester  Female
# 10              3.9   63218.0        Tester  Female
# 11              4.0   55794.0        Tester  Female
# 12              4.0   56957.0        Tester  Female
# 13              4.1   57081.0        Tester    Male
# 14              4.5   61111.0    Programmer    Male
# 15              4.9   67938.0    Programmer  Female
# 16              5.1   66029.0    Programmer  Female
# 17              5.3   83088.0     Developer    Male
# 18              5.9   81363.0     Developer    Male
# 19              6.0   93940.0     Developer  Female
# 20              6.8   91738.0     Developer  Female
# 21              7.1   98273.0     Developer  Female
# 22              7.9  101302.0     Developer  Female
# 23              8.2  113812.0     Marketing  Female
# 24              8.7  109431.0     Developer  Female
# 25              9.0  105582.0     Developer  Female
# 26              9.5  116969.0        Tester  Female
# 27              9.6  112635.0        Tester    Male
# 28             10.3  122391.0     Marketing    Male
# 29             10.5  121872.0     Marketing    Male
# 30              7.1   63218.0     Marketing    Male
# 31              7.9   55794.0     Marketing    Male
# 32              8.2   56957.0     Marketing    Male
# 33              NaN       NaN           NaN     NaN

# %%
plt.grid()
plt.plot(x,y)

# %%
df.head()
# Out:
#    YearsExperience   Salary      Position  Gender
# 0              1.1  39343.0     Developer    Male
# 1              1.3  46205.0  Data Analyst    Male
# 2              1.5  37731.0  Data Analyst  Female
# 3              2.0  43525.0  Data Analyst  Female
# 4              2.2  39891.0  Data Analyst  Female

# %%
df.any()
# Out:
# YearsExperience    True
# Salary             True
# Position           True
# Gender             True
# dtype: bool

# %%
df.all()
# Out:
# YearsExperience    True
# Salary             True
# Position           True
# Gender             True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# YearsExperience    1
# Salary             1
# Position           1
# Gender             1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     float64
#  2   Position         33 non-null     object
#  3   Gender           33 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
df['Salary'][0:10].mean()
# Out:
# 49956.6

# %%
df.describe(percentiles=[.55],include='all',)
# Out:
#         YearsExperience         Salary   Position  Gender
# count         33.000000      33.000000         33      33
# unique              NaN            NaN          5       2
# top                 NaN            NaN  Developer  Female
# freq                NaN            NaN         11      19
# mean           5.533333   74426.030303        NaN     NaN
# std            2.796054   26603.290663        NaN     NaN
# min            1.100000   37731.000000        NaN     NaN
# 50%            5.100000   63218.000000        NaN     NaN
# 55%            5.660000   65395.400000        NaN     NaN
# max           10.500000  122391.000000        NaN     NaN

# %%
df.describe(percentiles=[.55],include='all',)
# Out:
#         YearsExperience         Salary   Position  Gender
# count         33.000000      33.000000         33      33
# unique              NaN            NaN          5       2
# top                 NaN            NaN  Developer  Female
# freq                NaN            NaN         11      19
# mean           5.533333   74426.030303        NaN     NaN
# std            2.796054   26603.290663        NaN     NaN
# min            1.100000   37731.000000        NaN     NaN
# 50%            5.100000   63218.000000        NaN     NaN
# 55%            5.660000   65395.400000        NaN     NaN
# max           10.500000  122391.000000        NaN     NaN

# %%
df.describe(exclude='O')
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.533333   74426.030303
# std           2.796054   26603.290663
# min           1.100000   37731.000000
# 25%           3.200000   56642.000000
# 50%           5.100000   63218.000000
# 75%           7.900000   98273.000000
# max          10.500000  122391.000000

# %%
df.describe(exclude='O')
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.533333   74426.030303
# std           2.796054   26603.290663
# min           1.100000   37731.000000
# 25%           3.200000   56642.000000
# 50%           5.100000   63218.000000
# 75%           7.900000   98273.000000
# max          10.500000  122391.000000

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Columns: 4 entries, YearsExperience to Gender
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     float64
#  2   Position         33 non-null     object
#  3   Gender           33 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     float64
#  2   Position         33 non-null     object
#  3   Gender           33 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB

# %%
df.value_counts()
# Out:
# YearsExperience  Salary    Position      Gender
# 1.1              39343.0   Developer     Male      1
# 5.3              83088.0   Developer     Male      1
# 10.3             122391.0  Marketing     Male      1
# 9.6              112635.0  Tester        Male      1
# 9.5              116969.0  Tester        Female    1
# 9.0              105582.0  Developer     Female    1
# 8.7              109431.0  Developer     Female    1
# 8.2              113812.0  Marketing     Female    1
#                  56957.0   Marketing     Male      1
# 7.9              101302.0  Developer     Female    1
#                  55794.0   Marketing     Male      1
# 7.1              98273.0   Developer     Female    1
#                  63218.0   Marketing     Male      1
# 6.8              91738.0   Developer     Female    1
# 6.0              93940.0   Developer     Female    1
# 5.9              81363.0   Developer     Male      1
# 5.1              66029.0   Programmer    Female    1
# 1.3              46205.0   Data Analyst  Male      1
# 4.9              67938.0   Programmer    Female    1
# 4.5              61111.0   Programmer    Male      1
# 4.1              57081.0   Tester        Male      1
# 4.0              56957.0   Tester        Female    1
#                  55794.0   Tester        Female    1
# 3.9              63218.0   Tester        Female    1
# 3.7              57189.0   Tester        Female    1
# 3.2              64445.0   Tester        Female    1
#                  54445.0   Developer     Male      1
# 3.0              60150.0   Developer     Male      1
# 2.9              56642.0   Data Analyst  Female    1
# 2.2              39891.0   Data Analyst  Female    1
# 2.0              43525.0   Data Analyst  Female    1
# 1.5              37731.0   Data Analyst  Female    1
# 10.5             121872.0  Marketing     Male      1
# Name: count, dtype: int64

# %%
df['YearsExperience'].unique().sum()
# Out:
# nan

# %%
df.value_counts(normalize=True)
# Out:
# YearsExperience  Salary    Position      Gender
# 1.1              39343.0   Developer     Male      0.030303
# 5.3              83088.0   Developer     Male      0.030303
# 10.3             122391.0  Marketing     Male      0.030303
# 9.6              112635.0  Tester        Male      0.030303
# 9.5              116969.0  Tester        Female    0.030303
# 9.0              105582.0  Developer     Female    0.030303
# 8.7              109431.0  Developer     Female    0.030303
# 8.2              113812.0  Marketing     Female    0.030303
#                  56957.0   Marketing     Male      0.030303
# 7.9              101302.0  Developer     Female    0.030303
#                  55794.0   Marketing     Male      0.030303
# 7.1              98273.0   Developer     Female    0.030303
#                  63218.0   Marketing     Male      0.030303
# 6.8              91738.0   Developer     Female    0.030303
# 6.0              93940.0   Developer     Female    0.030303
# 5.9              81363.0   Developer     Male      0.030303
# 5.1              66029.0   Programmer    Female    0.030303
# 1.3              46205.0   Data Analyst  Male      0.030303
# 4.9              67938.0   Programmer    Female    0.030303
# 4.5              61111.0   Programmer    Male      0.030303
# 4.1              57081.0   Tester        Male      0.030303
# 4.0              56957.0   Tester        Female    0.030303
#                  55794.0   Tester        Female    0.030303
# 3.9              63218.0   Tester        Female    0.030303
# 3.7              57189.0   Tester        Female    0.030303
# 3.2              64445.0   Tester        Female    0.030303
#                  54445.0   Developer     Male      0.030303
# 3.0              60150.0   Developer     Male      0.030303
# 2.9              56642.0   Data Analyst  Female    0.030303
# 2.2              39891.0   Data Analyst  Female    0.030303
# 2.0              43525.0   Data Analyst  Female    0.030303
# 1.5              37731.0   Data Analyst  Female    0.030303
# 10.5             121872.0  Marketing     Male      0.030303
# Name: proportion, dtype: float64

# %%
df['YearsExperience'].value_counts(dropna=True)
# Out:
# YearsExperience
# 3.2     2
# 8.2     2
# 7.9     2
# 4.0     2
# 7.1     2
# 1.1     1
# 5.3     1
# 10.3    1
# 9.6     1
# 9.5     1
# 9.0     1
# 8.7     1
# 6.8     1
# 6.0     1
# 5.9     1
# 5.1     1
# 1.3     1
# 4.9     1
# 4.5     1
# 4.1     1
# 3.9     1
# 3.7     1
# 3.0     1
# 2.9     1
# 2.2     1
# 2.0     1
# 1.5     1
# 10.5    1
# Name: count, dtype: int64

# %%
df['Salary'].value_counts(dropna=True)
# Out:
# Salary
# 63218.0     2
# 55794.0     2
# 56957.0     2
# 39343.0     1
# 83088.0     1
# 122391.0    1
# 112635.0    1
# 116969.0    1
# 105582.0    1
# 109431.0    1
# 113812.0    1
# 101302.0    1
# 98273.0     1
# 91738.0     1
# 93940.0     1
# 81363.0     1
# 67938.0     1
# 66029.0     1
# 46205.0     1
# 61111.0     1
# 57081.0     1
# 57189.0     1
# 64445.0     1
# 54445.0     1
# 60150.0     1
# 56642.0     1
# 39891.0     1
# 43525.0     1
# 37731.0     1
# 121872.0    1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (34, 4)

# %%
df['Salary'][10:20].corr
# Out:
# <bound method Series.corr of 10    63218.0
# 11    55794.0
# 12    56957.0
# 13    57081.0
# 14    61111.0
# 15    67938.0
# 16    66029.0
# 17    83088.0
# 18    81363.0
# 19    93940.0
# Name: Salary, dtype: float64>

# %%
df.values
# Out:
# array([[1.1, 39343.0, 'Developer', 'Male'],
#        [1.3, 46205.0, 'Data Analyst', 'Male'],
#        [1.5, 37731.0, 'Data Analyst', 'Female'],
#        [2.0, 43525.0, 'Data Analyst', 'Female'],
#        [2.2, 39891.0, 'Data Analyst', 'Female'],
#        [2.9, 56642.0, 'Data Analyst', 'Female'],
#        [3.0, 60150.0, 'Developer', 'Male'],
#        [3.2, 54445.0, 'Developer', 'Male'],
#        [3.2, 64445.0, 'Tester', 'Female'],
#        [3.7, 57189.0, 'Tester', 'Female'],
#        [3.9, 63218.0, 'Tester', 'Female'],
#        [4.0, 55794.0, 'Tester', 'Female'],
#        [4.0, 56957.0, 'Tester', 'Female'],
#        [4.1, 57081.0, 'Tester', 'Male'],
#        [4.5, 61111.0, 'Programmer', 'Male'],
#        [4.9, 67938.0, 'Programmer', 'Female'],
#        [5.1, 66029.0, 'Programmer', 'Female'],
#        [5.3, 83088.0, 'Developer', 'Male'],
#        [5.9, 81363.0, 'Developer', 'Male'],
#        [6.0, 93940.0, 'Developer', 'Female'],
#        [6.8, 91738.0, 'Developer', 'Female'],
#        [7.1, 98273.0, 'Developer', 'Female'],
#        [7.9, 101302.0, 'Developer', 'Female'],
#        [8.2, 113812.0, 'Marketing', 'Female'],
#        [8.7, 109431.0, 'Developer', 'Female'],
#        [9.0, 105582.0, 'Developer', 'Female'],
#        [9.5, 116969.0, 'Tester', 'Female'],
#        [9.6, 112635.0, 'Tester', 'Male'],
#        [10.3, 122391.0, 'Marketing', 'Male'],
#        [10.5, 121872.0, 'Marketing', 'Male'],
#        [7.1, 63218.0, 'Marketing', 'Male'],
#        [7.9, 55794.0, 'Marketing', 'Male'],
#        [8.2, 56957.0, 'Marketing', 'Male'],
#        [nan, nan, nan, nan]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
corr=df[['Salary','YearsExperience']].corr()
print(corr)
# Out:
#                    Salary  YearsExperience
# Salary           1.000000         0.877385
# YearsExperience  0.877385         1.000000

# %%
df.plot(y='Salary',x='YearsExperience')
plt.ylabel('Salary Data')
plt.xlabel('Years of Experience')
plt.title("The Salary based on Year of Experience")
plt.yticks(np.arange(1,100000,1000))
plt.xticks(np.arange(1,12,1))
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
x=df['Salary']
y=df['YearsExperience']
fig=plt.figure(figsize=(20,20),facecolor="white")
ax1=fig.add_axes([.1,.2,.2,.2],facecolor='g',frameon=True)
plt.grid()
plt.yticks(np.arange(1,1000000,10000))
plt.xticks(np.arange(1,15,1))
ax1.plot(y,x,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
yearofexp=df['YearsExperience']
sal=df['Salary']

# %%
df
# Out:
#     YearsExperience    Salary      Position  Gender
# 0               1.1   39343.0     Developer    Male
# 1               1.3   46205.0  Data Analyst    Male
# 2               1.5   37731.0  Data Analyst  Female
# 3               2.0   43525.0  Data Analyst  Female
# 4               2.2   39891.0  Data Analyst  Female
# 5               2.9   56642.0  Data Analyst  Female
# 6               3.0   60150.0     Developer    Male
# 7               3.2   54445.0     Developer    Male
# 8               3.2   64445.0        Tester  Female
# 9               3.7   57189.0        Tester  Female
# 10              3.9   63218.0        Tester  Female
# 11              4.0   55794.0        Tester  Female
# 12              4.0   56957.0        Tester  Female
# 13              4.1   57081.0        Tester    Male
# 14              4.5   61111.0    Programmer    Male
# 15              4.9   67938.0    Programmer  Female
# 16              5.1   66029.0    Programmer  Female
# 17              5.3   83088.0     Developer    Male
# 18              5.9   81363.0     Developer    Male
# 19              6.0   93940.0     Developer  Female
# 20              6.8   91738.0     Developer  Female
# 21              7.1   98273.0     Developer  Female
# 22              7.9  101302.0     Developer  Female
# 23              8.2  113812.0     Marketing  Female
# 24              8.7  109431.0     Developer  Female
# 25              9.0  105582.0     Developer  Female
# 26              9.5  116969.0        Tester  Female
# 27              9.6  112635.0        Tester    Male
# 28             10.3  122391.0     Marketing    Male
# 29             10.5  121872.0     Marketing    Male
# 30              7.1   63218.0     Marketing    Male
# 31              7.9   55794.0     Marketing    Male
# 32              8.2   56957.0     Marketing    Male
# 33              NaN       NaN           NaN     NaN

# %%
plt.bar(yearofexp,sal, color='blue', edgecolor='black')
plt.xticks(np.arange(0,14,1))
plt.yticks(np.arange(0,100000,10000))
plt.xlabel("Salary")
plt.ylabel("Years of Experience")
plt.title("Salary of the employee based on Exp")
plt.legend(yearofexp,loc=9)
plt.grid()
plt.show()

# %%
plt.plot(yearofexp,sal)
